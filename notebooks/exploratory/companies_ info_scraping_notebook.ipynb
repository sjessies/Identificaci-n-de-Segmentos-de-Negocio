# %%
import requests
import pandas as pd
from pandas.core.frame import DataFrame
from bs4 import BeautifulSoup

# %%
# Specify the path to your Excel file
#excel_file_path = "data\raw\Forbes_2000_2023_all_companies.xlsx"
# Load the Excel file into a DataFrame
df_comp = pd.read_excel("C:\\Users\\sjess\\Identificaci-n-de-Segmentos-de-Negocio\\data\\raw\\Forbes_2000_2023_all_companies.xlsx")
# Display the DataFrame
df_comp
# Out:
#       RANK  UNIQUE_ID                                      NAME  \
# 0        1          1                            JPMorgan Chase
# 1        2          2  Saudi Arabian Oil Company (Saudi Aramco)
# 2        3          3                                      ICBC
# 3        4          4                   China Construction Bank
# 4        5          5                Agricultural Bank of China
# ...    ...        ...                                       ...
# 1995  1996       1996                                Alfa Laval
# 1996  1996       1997                                       Gap
# 1997  1996       1998                                  Yes Bank
# 1998  1999       1999                                 BEKB-BCBE
# 1999  1999       2000                                     Ipsen
#
#             COUNTRY     SALES     PROFIT       ASSETS  MARKET VALUE   \
# 0     United States  $179.93 B    $41.8 B   $3,744.3 B     $399.59 B
# 1      Saudi Arabia  $589.47 B  $156.36 B    $660.99 B   $2,055.22 B
# 2             China  $216.77 B   $52.47 B  $6,116.82 B     $203.01 B
# 3             China  $203.08 B   $48.25 B  $4,977.48 B     $172.99 B
# 4             China  $186.14 B   $37.92 B  $5,356.86 B     $141.82 B
# ...             ...        ...        ...          ...           ...
# 1995         Sweden     $5.4 B   $489.5 M       $7.8 B       $15.6 B
# 1996  United States    $15.6 B    $-202 M      $11.4 B        $3.2 B
# 1997          India     $3.3 B    $91.6 M      $43.2 B        $5.6 B
# 1998    Switzerland     $556 M   $167.1 M        $43 B        $2.5 B
# 1999         France     $3.2 B   $681.7 M         $6 B       $10.2 B
#
#                                     URL-NAME
# 0                             jpmorgan-chase
# 1     saudi-arabian-oil-company-saudi-aramco
# 2                                       icbc
# 3                    china-construction-bank
# 4                 agricultural-bank-of-china
# ...                                      ...
# 1995                              alfa-laval
# 1996                                     gap
# 1997                                yes-bank
# 1998                               bekb-bcbe
# 1999                                   ipsen
#
# [2000 rows x 9 columns]

# %%
def getData(company_name):
  """
  Extracts data from a Forbes company page.
  Args:
    company_name: The name of the company.
  Returns:
    A dictionary containing the extracted data.
  """

  # Set the URL of the Forbes company page.
  url = f"https://www.forbes.com/companies/{company_name}"

  # Make a GET request to the URL.
  r = requests.get(url)

  # Parse the HTML response using BeautifulSoup.
  soup = BeautifulSoup(r.text, "html.parser")

  # Extract company basic information
  # Get the company name.
  company_name = soup.find("h1", class_="listuser-header__name")
  company_name = company_name.text if company_name else ""

  # Get the stock ticker.
  stock_ticker = soup.find("div", class_="listuser-ticker")
  stock_ticker = stock_ticker.text if stock_ticker else ""

  # Get the company headquarters location.
  company_location = soup.find("div", class_="listuser-header__headline--premium-location")
  company_location = company_location.text if company_location else ""

  # Get the current stock price.
  current_stock_price = soup.find("div", class_="profile-info__item-value")
  current_stock_price = current_stock_price.text if current_stock_price else ""

  # Create a dictionary with the extracted data.
  company_basic = {
    "company_name": company_name,
    "stock_ticker": stock_ticker,
    "company_location": company_location,
    "current_stock_price": current_stock_price
  }

  # Get the company description.
  if soup.find("div", class_="listuser-content__bio--shortened") is not None:
    value = soup.find("div", class_="listuser-content__bio--expanded hidden").text
  else:
    value = soup.find("p", class_="listuser-content__bio--copy").text

  # Create a dictionary with the description
  description_dict = {"description": value}

  # Get the company stats.
  company_stats = {}
  for element in soup.findAll("dl", class_="listuser-block__item"):
    dt = element.find("dt", class_="profile-stats__title")
    dd = element.find("dd", class_="profile-stats__text")
    company_stats[dt.text] = dd.text

  # Get the company financial data for a specific data index (e.g., "0").
  data_index = "0"
  company_financial_data = {}

  # Find the financial data div with the specified data index.
  financial_data_div = soup.find("div", {"class": "listuser-financial-data", "data-index": data_index})

  if financial_data_div:
    for element in financial_data_div.findAll("div", class_="listuser-financial-item"):
        title = element.find("div", class_="listuser-financial-item__title").text
        value = element.find("div", class_="listuser-financial-item__value").text
        company_financial_data[title] = value

  # Get the key data.
  key_data = {}
  for div in soup.find_all('div', class_='profile-datapoint__data'):
    title = div.find('div', class_='profile-datapoint__data-title').text.strip()
    value = div.find('span', class_='profile-datapoint__data-value').text.strip()
    key_data[title] = value

  # Create a new dictionary by merging dict1 and dict2
  data = {**company_basic,**description_dict,**company_stats,**company_financial_data,**key_data}

  # Return the extracted data.
  return data

# %%
# Extract the "URL-NAME" column and convert it to a list
companies = df_comp['URL-NAME'].tolist()

# Display the list
companies
# Out:
# ['jpmorgan-chase',
#  'saudi-arabian-oil-company-saudi-aramco',
#  'icbc',
#  'china-construction-bank',
#  'agricultural-bank-of-china',
#  'bank-of-america',
#  'alphabet',
#  'exxonmobil',
#  'microsoft',
#  'apple',
#  'shell',
#  'bank-of-china',
#  'toyota-motor',
#  'samsung-electronics',
#  'unitedhealth-group',
#  'ping-an-insurance-group',
#  'wells-fargo',
#  'chevron',
#  'petrochina',
#  'hsbc-holdings',
#  'totalenergies',
#  'verizon-communications',
#  'walmart',
#  'citigroup',
#  'china-mobile',
#  'china-merchants-bank',
#  'postal-savings-bank-of-china-psbc',
#  'bp',
#  'volkswagen-group',
#  'morgan-stanley',
#  'meta-platforms',
#  'sinopec',
#  'bnp-paribas',
#  'goldman-sachs-group',
#  'tencent-holdings',
#  'amazon',
#  'allianz',
#  'rbc',
#  'pfizer',
#  'johnson--johnson',
#  'deutsche-telekom',
#  'mercedes-benz-group',
#  'td-bank-group',
#  'taiwan-semiconductor',
#  'reliance-industries',
#  'bmw-group',
#  'lvmh-moët-hennessy-louis-vuitton',
#  'axa-group',
#  'santander',
#  'nestlé',
#  'comcast',
#  'equinor',
#  'bank-of-communications',
#  'alibaba-group',
#  'procter--gamble',
#  'nippon-telegraph--tel',
#  'sony',
#  'petrobras',
#  'glencore-international',
#  'industrial-bank',
#  'stellantis',
#  'china-life-insurance',
#  'american-express',
#  'general-electric',
#  'cvs-health',
#  'china-state-construction-engineering',
#  'the-home-depot',
#  'cigna',
#  'tesla',
#  'general-motors',
#  'citic',
#  'anheuser-busch-inbev',
#  'merck--co.',
#  'abbvie',
#  'mitsubishi',
#  'roche-holding',
#  'state-bank-of-india',
#  'elevance-health',
#  'raytheon-technologies',
#  'oracle',
#  'eni',
#  'pepsico',
#  'conocophillips',
#  'bank-of-montreal',
#  'cnooc',
#  'sumitomo-mitsui-financial',
#  'walt-disney',
#  'bank-of-nova-scotia',
#  'sanofi',
#  'bhp-group',
#  'mitsubishi-ufj-financial',
#  'ubs',
#  'cisco-systems',
#  'novartis',
#  'united-parcel-service',
#  'coca-cola',
#  'siemens',
#  'itaú-unibanco-holding',
#  'costco-wholesale',
#  'commonwealth-bank',
#  'rio-tinto',
#  'iberdrola',
#  'bbva-banco-bilbao-vizcaya',
#  'hyundai-motor',
#  'unilever',
#  'zurich-insurance-group',
#  'deere--company',
#  'mitsui',
#  'honda-motor',
#  'british-american-tobacco',
#  'bristol-myers-squibb',
#  'chubb',
#  'intesa-sanpaolo',
#  'munich-re',
#  'shanghai-pudong-development',
#  'hon-hai-precision',
#  'marathon-petroleum',
#  'thermo-fisher-scientific',
#  'caterpillar',
#  'charles-schwab',
#  'contemporary-amperex-technology',
#  'visa',
#  'american-international-group',
#  'ford-motor',
#  'itochu',
#  'astrazeneca',
#  'airbus',
#  'hdfc-bank',
#  'credit-agricole',
#  'vinci',
#  'china-shenhua-energy',
#  'us-bancorp',
#  'china-citic-bank',
#  'broadcom',
#  'nextera-energy',
#  'phillips-66',
#  'bayer',
#  'charter-communications',
#  'vale',
#  'nab---national-australia-bank',
#  'hitachi',
#  'abbott-laboratories',
#  'japan-post-holdings',
#  'anz',
#  'danaher',
#  'china-telecom',
#  'lloyds-banking-group',
#  'capital-one',
#  'pnc-financial-services',
#  'brookfield-corporation',
#  'picc',
#  'generali-group',
#  'mizuho-financial',
#  'deutsche-post',
#  'truist-financial',
#  'china-pacific-insurance',
#  'amgen',
#  'kddi',
#  'lockheed-martin',
#  'accenture',
#  "lowe's",
#  'linde',
#  'icici-bank',
#  'barclays',
#  'valero-energy',
#  'philip-morris-international',
#  'fedex',
#  'metlife',
#  'occidental-petroleum',
#  'byd',
#  'banco-do-brasil',
#  'medtronic',
#  'banco-bradesco',
#  'moller-maersk',
#  'ibm',
#  'unicredit',
#  'américa-móvil',
#  'enel',
#  'southern-company',
#  'qualcomm',
#  'oversea-chinese-banking',
#  "l'oréal",
#  'canadian-imperial-bank',
#  'hca-healthcare',
#  'duke-energy',
#  'honeywell-international',
#  'gsk',
#  'deutsche-bank',
#  'mckesson',
#  'dbs',
#  'china-everbright-bank',
#  'mondelez-international',
#  'tokio-marine-holdings',
#  'union-pacific',
#  'enbridge',
#  'porsche-automobil-holding',
#  'westpac-banking-group',
#  'china-railway-group',
#  'midea-group',
#  'ing-group',
#  'eli-lilly',
#  'humana',
#  'target',
#  'archer-daniels-midland',
#  'natwest-group',
#  'schneider-electric',
#  'national-grid',
#  'qatar-national-bank',
#  'e.on',
#  'china-minsheng-bank',
#  'nike',
#  'gilead-sciences',
#  'rwe-group',
#  'arcelormittal',
#  'blackrock',
#  'suncor-energy',
#  "mcdonald's",
#  'canadian-natural-resources',
#  'nordea-bank',
#  'china-resources-land',
#  'sap',
#  'travelers',
#  'netflix',
#  'jd.com',
#  'dell-technologies',
#  'oil--natural-gas',
#  'ck-hutchison',
#  'china-vanke',
#  'vodafone',
#  'volvo-group',
#  'seven--i-holdings',
#  'hdfc',
#  'bank-of-new-york-mellon',
#  'anglo-american',
#  'mastercard',
#  'novo-nordisk',
#  'northrop-grumman',
#  'ptt',
#  'paypal',
#  'asml-holding',
#  'nvidia',
#  '3m',
#  'poly-developments--holdings-group',
#  'general-dynamics',
#  'macquarie-group',
#  'eog-resources',
#  'takeda-pharmaceutical',
#  'air-liquide',
#  'aflac',
#  'sun-life-financial',
#  'orange',
#  'cosco-shipping',
#  'kraft-heinz-company',
#  'nutrien',
#  'standard-chartered',
#  'kia',
#  'dow',
#  'saic-motor',
#  'centene',
#  'the-saudi-national-bank',
#  'sumitomo',
#  'essilorluxottica',
#  'merck-kgaa-germany',
#  'schlumberger',
#  'china-railway-construction',
#  'kroger',
#  'marubeni',
#  'holcim',
#  'dai-ichi-life-insurance',
#  'nippon-steel',
#  'denso',
#  'royal-ahold-delhaize-n.v.',
#  'inditex',
#  'kbc-group',
#  'diageo',
#  'manulife',
#  'china-unicom',
#  'kb-financial-group',
#  'sk-hynix',
#  'saint-gobain',
#  'cheniere-energy',
#  'daimler-truck-holding',
#  'pkn-orlen',
#  'zijin-mining-group',
#  'kweichow-moutai',
#  'telefónica',
#  'amerisourcebergen',
#  'al-rajhi-bank',
#  'power-construction-corporation-of-china',
#  'repsol',
#  'first-abu-dhabi-bank',
#  'fiserv',
#  'automatic-data-processing',
#  'enbw-energie-baden',
#  'tjx-cos',
#  'saudi-electricity',
#  'caixabank',
#  'abb',
#  'posco',
#  'shinhan-financial-group',
#  'altria-group',
#  'starbucks',
#  'power-corp-of-canada',
#  'crh',
#  'international-holding-company',
#  'exelon',
#  'longfor-group-holdings',
#  'bank-rakyat-indonesia-bri',
#  'woodside-energy-group',
#  'american-electric',
#  'ecopetrol',
#  'femsa',
#  'sempra',
#  'société-générale',
#  'texas-instruments',
#  'applied-materials',
#  'pioneer-natural-resources',
#  'bank-of-ningbo',
#  'nucor',
#  'cenovus-energy',
#  'bank-of-jiangsu',
#  'micron-technology',
#  'couche-tard',
#  'pge',
#  'freeport-mcmoran',
#  'huaxia-bank',
#  'united-overseas-bank',
#  'kering',
#  'emirates-nbd',
#  'shin-etsu-chemical',
#  'gree-electric-appliances',
#  'discover-financial-services',
#  'citic-securities',
#  'lennar',
#  'china-communications-construction',
#  'pdd-holdings',
#  'progressive',
#  'berkshire-hathaway',
#  'lg-chem',
#  'd.r.-horton',
#  'principal-financial-group',
#  'delta-air-lines',
#  'marsh--mclennan',
#  'dnb-bank',
#  'corebridge-financial',
#  'wilmar-international',
#  'ameriprise-financial',
#  'bank-of-beijing',
#  'kinder-morgan',
#  'fannie-mae',
#  'lyondellbasell-industries',
#  'stryker',
#  'dollar-general',
#  'japan-tobacco',
#  'hp',
#  'panasonic',
#  'omv-group',
#  'paccar',
#  'csx',
#  'becton-dickinson',
#  'sp-global',
#  'eaton',
#  'life-insurance-corp.-of-india',
#  'state-street',
#  'analog-devices',
#  'adobe',
#  'freddie-mac',
#  'nokia',
#  'saudi-telecom',
#  'att',
#  'orix',
#  'banco-btg-pactual',
#  'national-bank-of-canada',
#  'bce',
#  'banorte',
#  'canadian-national-railway',
#  'taqa',
#  'daikin-industries',
#  'consolidated-edison',
#  'reckitt-benckiser-group',
#  'swiss-life-holding',
#  'naturgy-energy-group',
#  'msad-insurance',
#  'shaanxi-coal-industry',
#  'poste-italiane',
#  'general-mills',
#  'tata-consultancy-services',
#  'baoshan-iron--steel',
#  'seb-ab',
#  'wm',
#  'erste-group-bank',
#  'tyson-foods',
#  'booking-holdings',
#  'koç-holding',
#  'bae-systems',
#  'heineken',
#  'united-airlines-holdings',
#  'haier-smart-home',
#  'johnson-controls-international',
#  'cummins',
#  'wanhua-chemical-group',
#  'edf',
#  'bank-of-shanghai',
#  'china-yangtze-power',
#  'bt-group',
#  'crrc',
#  'hartford-financial-services',
#  'dominion-energy',
#  'mitsubishi-electric',
#  'etisalat',
#  'fresenius',
#  'toyota-tsusho',
#  'bridgestone',
#  'fortescue-metals-group',
#  'cez-group',
#  'xcel-energy',
#  'eneos-holdings',
#  'bank-mandiri',
#  'talanx',
#  'hana-financial-group',
#  'tesco',
#  'intel',
#  'axis-bank',
#  'nissan-motor',
#  'aia-group',
#  'marriott-international',
#  'boeing',
#  'credit-suisse-group',
#  'carrefour',
#  'danone',
#  'yankuang-energy-group',
#  'regeneron-pharmaceuticals',
#  'canon',
#  'ntpc',
#  'emerson-electric',
#  'london-stock-exchange',
#  'intercontinentalexchange',
#  'norfolk-southern',
#  'pernod-ricard',
#  'michelin-group',
#  'komatsu',
#  'softbank',
#  'dupont-de-nemours',
#  'sysco',
#  'devon-energy',
#  'orsted',
#  'american-tower',
#  'lam-research',
#  'fairfax-financial',
#  'larsen--toubro',
#  'infineon-technologies',
#  'investor-ab',
#  'aon',
#  'bank-of-nanjing',
#  'baidu',
#  'dsv-panalpina',
#  'engie',
#  'sherwin-williams',
#  'sun-hung-kai-properties',
#  'daiwa-house-industry',
#  'prologis',
#  'bank-central-asia',
#  'moderna',
#  'hyundai-mobis',
#  'mt-bank',
#  'carrier-global',
#  'csl',
#  'cnh-industrial',
#  'grupo-mexico',
#  'keurig-dr-pepper',
#  'ge-healthcare',
#  'maybank',
#  'toyota-industries',
#  'commerzbank',
#  'corteva',
#  'tc-energy',
#  'bharti-airtel',
#  'williams',
#  'henkel',
#  'veolia-environnement',
#  'fifth-third-bank',
#  'fast-retailing',
#  's.f.-holding',
#  'intuit',
#  'prudential-financial',
#  'salesforce',
#  'china-coal-energy',
#  'firstrand',
#  'svenska-handelsbanken',
#  'netease',
#  'lenovo-group',
#  'new-china-life-insurance',
#  'cme-group',
#  'recruit-holdings',
#  'tongwei',
#  'swedbank',
#  'basf',
#  'intact-financial',
#  'george-weston',
#  'parker-hannifin',
#  'air-products--chemicals',
#  'kotak-mahindra-bank',
#  'edison-international',
#  'standard-bank-group',
#  'muyuan-foodstuff',
#  'imperial-brands',
#  'mitsui-fudosan',
#  'public-service-enterprise-group',
#  'stmicroelectronics',
#  'inpex',
#  'canadian-pacific-kansas-city',
#  'naspers',
#  'samsung-ct',
#  'alpha-dhabi-holding',
#  'capgemini',
#  'compass-group',
#  'oneok',
#  'kenvue',
#  'swiss-re',
#  'dollar-tree',
#  'suzuki-motor',
#  'synchrony-financial',
#  'haleon',
#  'bouygues',
#  'hermès-international',
#  'coca-cola-europacific-partners',
#  'sinopharm-group',
#  'raymond-james-financial',
#  'ericsson',
#  'longi-green-energy-technology',
#  'woolworths',
#  'thales',
#  'wuliangye-yibin',
#  'eversource-energy',
#  'walgreens-boots-alliance',
#  'american-airlines-group',
#  'kuehne--nagel-international',
#  'wesfarmers',
#  'anhui-conch-cement',
#  'indian-oil',
#  'cathay-financial',
#  'central-japan-railway',
#  'nxp-semiconductors',
#  'republic-services',
#  'fujitsu',
#  'saudi-arabian-mining',
#  'ctbc-financial',
#  'halliburton',
#  'hewlett-packard-enterprise',
#  'vmware',
#  'fujifilm-holdings',
#  'nintendo',
#  'citizens-financial-group',
#  'kimberly-clark',
#  'infosys',
#  'tokyo-electron',
#  'teck-resources',
#  'sumitomo-mitsui-trust',
#  'warner-bros.-discovery',
#  'mediatek',
#  'illinois-tool-works',
#  'woori-financial-group',
#  'jbs',
#  'dte-energy',
#  'metallurgical-corp-of-china',
#  'samsung-life-insurance',
#  'nippon-yusen',
#  'advanced-micro-devices',
#  'huntington-bank',
#  'arch-capital-group',
#  'te-connectivity',
#  'bunge',
#  'china-zheshang-bank',
#  'allstate',
#  'luxshare-precision-industry',
#  'jackson-financial',
#  'albertsons',
#  'heidelbergcement',
#  'edp-energias-de-portugal',
#  'entergy',
#  'evergreen-marine-corp.-taiwan',
#  'l3harris-technologies',
#  'deutsche-boerse',
#  'atlas-copco',
#  'regions-financial',
#  'bank-of-baroda',
#  'telus',
#  'boston-scientific',
#  'cognizant',
#  'samsung-sdi',
#  'coal-india',
#  'tata-steel',
#  'asahi-group-holdings',
#  'china-tower-corp.',
#  'the-estée-lauder-companies',
#  'riyad-bank',
#  'mgm-resorts',
#  'biogen',
#  'neste',
#  'east-japan-railway',
#  'telstra',
#  'ferguson',
#  'kubota',
#  'colgate-palmolive',
#  'kuwait-finance-house',
#  'autozone',
#  'raiffeisen-bank-international',
#  'china-merchants-shekou-industrial-zone-holdings',
#  'sompo',
#  'grupo-bimbo',
#  'china-national-nuclear-power',
#  'hess',
#  'ck-asset-holdings',
#  'singtel',
#  'deutsche-lufthansa',
#  'rogers-communications',
#  'legal--general-group',
#  'publicis-groupe',
#  'swisscom',
#  'mitsubishi-heavy-industries',
#  'sk',
#  'vertex-pharmaceuticals',
#  'sichuan-road--bridge',
#  'viatris',
#  'bank-of-hangzhou',
#  'idemitsu-kosan',
#  'sse',
#  'industrial-bank-of-korea',
#  'china-energy-engineering',
#  'wec-energy-group',
#  'hanwha',
#  'trane-technologies',
#  'ppg',
#  'volvo-car',
#  'weichai-power',
#  'meituan',
#  'cbre-group',
#  'crown-castle-international',
#  'diamondback-energy',
#  'activision-blizzard',
#  'xiamen-cd',
#  'cgn-power',
#  'sampo',
#  'inner-mongolia-yili',
#  'northern-trust',
#  'aeon',
#  'murata-manufacturing',
#  'blackstone',
#  'cardinal-health',
#  'loews',
#  'abu-dhabi-commercial-bank',
#  'ecolab',
#  'relx',
#  'safran',
#  'uber',
#  'nomura',
#  'iqvia',
#  'united-rentals',
#  'gallagher',
#  'prudential',
#  'equitable-holdings',
#  'hindalco-industries',
#  'the-mosaic-company',
#  'norsk-hydro',
#  'richemont',
#  "o'reilly-automotive",
#  'subaru',
#  'national-bank-of-kuwait',
#  'toshiba',
#  'xiaomi',
#  'ase-technology-holding',
#  'kyocera',
#  'hikvision',
#  'chongqing-changan-auto',
#  'mitsubishi-estate',
#  'boe-technology-group',
#  'turkish-airlines',
#  'jfe-holdings',
#  'china-national-building',
#  'tbea',
#  'ross-stores',
#  'keyence',
#  'quinenco',
#  'best-buy',
#  'renesas-electronics',
#  'amphenol',
#  'kla',
#  'vedanta-limited',
#  'danske-bank',
#  'ally-financial',
#  'corning',
#  'genuine-parts',
#  'steel-dynamics',
#  'reinsurance-group-of-america',
#  'hong-kong-exchanges',
#  'daqin-railway',
#  'isbank',
#  'verbund',
#  'bajaj-finserv',
#  'semiconductor-manufacturing-international',
#  'southwest-airlines',
#  'fortis-canada',
#  'sk-innovation',
#  'associated-british-foods',
#  'jardine-matheson',
#  'keycorp',
#  'zte',
#  'sekisui-house',
#  'omnicom-group',
#  'grasim-industries',
#  'quanta-computer',
#  'sabanci-holding',
#  'rongsheng-petrochemical',
#  'international-paper',
#  'eiffage',
#  'tenaris',
#  'tokyo-gas',
#  'korea-gas',
#  'fox',
#  'siemens-energy',
#  'qbe-insurance-group',
#  'mahindra--mahindra',
#  'dish-network',
#  'constellation-energy',
#  'tata-motors',
#  'westlake-chemical',
#  'bank-leumi',
#  'canara-bank',
#  'ww-grainger',
#  'hd-hyundai',
#  'huishang-bank',
#  'coterra-energy',
#  'fubon-financial',
#  'airbnb',
#  'aercap-holdings',
#  'simon-property-group',
#  'renault',
#  'equinix',
#  'solvay',
#  'public-bank',
#  'lg-electronics',
#  'fidelity-national-information-fis',
#  'upm-kymmene',
#  'nec',
#  'ameren',
#  'wtw',
#  'eqt',
#  'korea-electric-power',
#  'thyssenkrupp-group',
#  'ypf',
#  'the-hershey-company',
#  'itc',
#  'microchip-technology',
#  'mtr',
#  'bank-hapoalim',
#  'targa-resources',
#  'hcl-technologies',
#  'saudi-british-bank',
#  'tenaga-nasional',
#  'vici-properties',
#  'pultegroup',
#  'sodexo',
#  'wpp',
#  'bank-of-ireland',
#  'builders-firstsource',
#  'santos',
#  'pembina-pipeline',
#  'albemarle',
#  'baker-hughes-company',
#  'cimb-group-holdings',
#  'otsuka-holding',
#  'zoetis',
#  'hf-sinclair',
#  'suzano',
#  'mitsui-osk-lines',
#  'realty-income',
#  'apollo-global-management',
#  'w.-r.-berkley',
#  'labcorp',
#  'unum',
#  'shanghai-rural-commercial-bank',
#  'public-storage',
#  'country-garden-holdings',
#  'cdw',
#  'huatai-securities',
#  'centerpoint-energy',
#  'grupo-acs',
#  'telkom-indonesia',
#  'united-microelectronics',
#  'aptiv',
#  'samsung-fire--marine',
#  'nn-group',
#  'china-hongqiao-group',
#  'otis-worldwide',
#  'sasol',
#  'yara-international',
#  'continental',
#  'sumitomo-electric',
#  'china-bohai-bank',
#  'nan-ya-plastics',
#  'guotai-junan-securities',
#  'block',
#  'aluminum-corp-of-china',
#  'emaar-properties',
#  'kellogg',
#  'sqm',
#  'ashtead-group',
#  'daiichi-sankyo',
#  'power-finance',
#  'thomson-reuters',
#  'galp-energia',
#  'absa-group',
#  'assa-abloy',
#  'essity',
#  'joint-stock-commercial-bank-for-foreign-trade-of-vietnam',
#  'first-citizens-bank-nc',
#  'henderson-land',
#  'huaneng-power-international',
#  'east-money-information',
#  'chesapeake-energy',
#  'sika',
#  'chongqing-rural-bank',
#  'resona-holdings',
#  'jabil-circuit',
#  'hmm',
#  'aegon',
#  'globalfoundries',
#  'mol-hungarian-oil',
#  'ageas',
#  'hengli-petrochemical',
#  'mitsubishi-ufj-lease',
#  'greenland-holdings-group',
#  'dongfeng-motor-group',
#  'shanghai-pharmaceuticals',
#  'roper-technologies',
#  'celanese',
#  'julius-baer-group',
#  'isuzu-motors',
#  'td-synnex',
#  'motorola-solutions',
#  'china-molybdenum',
#  'gs-holdings',
#  'great-wall-motor',
#  'sandvik',
#  'air-france-klm',
#  'ppl',
#  'hilton-worldwide-holdings',
#  'everest-re-group',
#  'kasikornbank',
#  'china-resources-power',
#  'barrick-gold',
#  'molina-healthcare',
#  'tdk',
#  'magna-international',
#  'power-grid-of-india',
#  'union-bank-of-india',
#  'newmont-mining',
#  'paramount',
#  'geely-automobile-holdings',
#  'guosen-securities',
#  'wipro',
#  'lonza-group',
#  'china-national-chemical',
#  'tractor-supply',
#  'gemdale',
#  'adidas',
#  'sunshine-insurance-group',
#  'ryanair-holdings',
#  'gf-securities',
#  'reliance-steel',
#  'sm-investments',
#  'delta-electronics',
#  'kkr',
#  'firstenergy',
#  'cnpc-capital',
#  'scb-x-public-company',
#  'gd-power-development',
#  'kansai-electric-power',
#  'on-semiconductor-corp.',
#  'siam-cement',
#  'legend-holding',
#  'china-cinda-asset-management',
#  'shanghai-international-port',
#  'china-taiping-insurance',
#  'cintas',
#  'conagra-brands',
#  'arrow-electronics',
#  'fortum',
#  'jsw-steel',
#  'mitsubishi-chemical',
#  'jiangxi-copper',
#  'philips',
#  'stanley-black--decker',
#  'mtn-group',
#  'tokyo-electric-power',
#  'mapfre',
#  'bancolombia',
#  'dubai-islamic-bank',
#  'agnico-eagle-mines',
#  'antarchile',
#  'amcor',
#  'pbf-energy',
#  'bdo-unibank',
#  'chipotle-mexican-grill',
#  'tcl-zhonghuan-renewable-energy-technology',
#  'expeditors-international',
#  'china-three-gorges-renewables-group',
#  'shanghai-construction',
#  'alinma-bank',
#  'wh-group',
#  'stora-enso',
#  'mazda-motor',
#  'marathon-oil',
#  'link-reit',
#  'coles-group',
#  'avis-budget-group',
#  'unipol-gruppo',
#  'astellas-pharma',
#  'flex',
#  'fidelity-national-financial',
#  'kt',
#  '3i-group',
#  'penske-automotive',
#  'intuitive-surgical',
#  'new-york-community-bancorp',
#  'sumitomo-realty',
#  'chunghwa-telecom',
#  'eletrobrás',
#  'sumitomo-metal-mining',
#  'weyerhaeuser',
#  'bank-negara-indonesia',
#  'cp-all',
#  'ulta-beauty',
#  'asahi-kasei',
#  'international-flavors--fragrances',
#  'techtronic-industries',
#  'global-payments',
#  'suncorp-group',
#  'brookfield-renewable',
#  'grupa-pzu',
#  'cf-industries-holdings',
#  'kirin-holdings',
#  'legrand',
#  'nvr',
#  'cms-energy',
#  'baxter-international',
#  'rockwell-automation',
#  'rolls-royce-holdings',
#  'china-merchants-securities',
#  'credicorp',
#  'enn-natural-gas',
#  'universal-music-group',
#  'us-steel',
#  'mercadolibre',
#  'international-airlines',
#  'markel',
#  'ovintiv',
#  'enn-energy-holdings',
#  'mizrahi-tefahot-bank',
#  'monster-beverage',
#  'carnival-corporation',
#  'meritz-financial-group',
#  'hormel-foods',
#  'china-mengniu-dairy',
#  'otp-bank',
#  'china-international-capital',
#  'kone',
#  'mega-financial-holding',
#  'sany-heavy-industry',
#  'cgi',
#  'lincoln-national',
#  'bank-of-chengdu',
#  'nidec',
#  'fosun-international',
#  'j.b.-hunt-transport-services',
#  'guangzhou-automobile-group',
#  'nasdaq',
#  'yang-ming-marine-transport',
#  'carmax',
#  'gerdau-cosigua',
#  'formosa-plastics',
#  'tcl',
#  'waste-connections',
#  'bayan-resources',
#  'jeronimo-martins',
#  'chubu-electric-power',
#  'agilent-technologies',
#  'restaurant-brands-international',
#  'south32',
#  'brenntag',
#  'banque-saudi-fransi',
#  'taiwan-cooperative-financial',
#  'wens-foodstuff-group',
#  'leonardo',
#  'smc',
#  'lufax-holding',
#  'td-holdings',
#  'anta-sports-products',
#  "moody's",
#  'vestas-wind-systems',
#  ...]

# %%
# Initialize an empty list to store data for each company
company_data_list = []

# Initialize an empty list to store company names with errors
comp_errors = []

# Iterate through the list of companies and extract data
for company_name in companies:
    try:
        company_data = getData(company_name)  # Assuming you have your getData function defined
        company_data_list.append(company_data)
    except Exception as e:
        # Handle the exception (e.g., print an error message)
        print(f"Error fetching data for {company_name}: {str(e)}")
        # Add the problematic company name to the error list
        comp_errors.append(company_name)

# Create a Pandas DataFrame from the list of company data
df = pd.DataFrame(company_data_list)

# Display the list of companies with errors
print("Companies with errors:", comp_errors)
# Out:
# Error fetching data for jpmorgan-chase: 'NoneType' object has no attribute 'text'
# Error fetching data for saudi-arabian-oil-company-saudi-aramco: 'NoneType' object has no attribute 'text'
# Error fetching data for icbc: 'NoneType' object has no attribute 'text'
# Error fetching data for china-construction-bank: 'NoneType' object has no attribute 'text'
# Error fetching data for agricultural-bank-of-china: 'NoneType' object has no attribute 'text'
# Error fetching data for bank-of-america: 'NoneType' object has no attribute 'text'
# Error fetching data for alphabet: 'NoneType' object has no attribute 'text'
# Error fetching data for exxonmobil: 'NoneType' object has no attribute 'text'
# Error fetching data for microsoft: 'NoneType' object has no attribute 'text'
# Error fetching data for apple: 'NoneType' object has no attribute 'text'
# Error fetching data for shell: 'NoneType' object has no attribute 'text'
# Error fetching data for bank-of-china: 'NoneType' object has no attribute 'text'
# Error fetching data for toyota-motor: 'NoneType' object has no attribute 'text'
# Error fetching data for samsung-electronics: 'NoneType' object has no attribute 'text'
# Error fetching data for unitedhealth-group: 'NoneType' object has no attribute 'text'
# Error fetching data for ping-an-insurance-group: 'NoneType' object has no attribute 'text'
# Error fetching data for wells-fargo: 'NoneType' object has no attribute 'text'
# Error fetching data for chevron: 'NoneType' object has no attribute 'text'
# Error fetching data for petrochina: 'NoneType' object has no attribute 'text'
# Error fetching data for hsbc-holdings: 'NoneType' object has no attribute 'text'
# Error fetching data for totalenergies: 'NoneType' object has no attribute 'text'
# Error fetching data for verizon-communications: 'NoneType' object has no attribute 'text'
# Error fetching data for walmart: 'NoneType' object has no attribute 'text'
# Error fetching data for citigroup: 'NoneType' object has no attribute 'text'
# Error fetching data for china-mobile: 'NoneType' object has no attribute 'text'
# Error fetching data for china-merchants-bank: 'NoneType' object has no attribute 'text'
# Error fetching data for postal-savings-bank-of-china-psbc: 'NoneType' object has no attribute 'text'
# Error fetching data for bp: 'NoneType' object has no attribute 'text'
# Error fetching data for volkswagen-group: 'NoneType' object has no attribute 'text'
# Error fetching data for morgan-stanley: 'NoneType' object has no attribute 'text'
# Error fetching data for meta-platforms: 'NoneType' object has no attribute 'text'
# Error fetching data for sinopec: 'NoneType' object has no attribute 'text'
# Error fetching data for bnp-paribas: 'NoneType' object has no attribute 'text'
# Error fetching data for goldman-sachs-group: 'NoneType' object has no attribute 'text'
# Error fetching data for tencent-holdings: 'NoneType' object has no attribute 'text'
# Error fetching data for amazon: 'NoneType' object has no attribute 'text'
# Error fetching data for allianz: 'NoneType' object has no attribute 'text'
# Error fetching data for rbc: 'NoneType' object has no attribute 'text'
# Error fetching data for johnson--johnson: 'NoneType' object has no attribute 'text'
# Error fetching data for deutsche-telekom: 'NoneType' object has no attribute 'text'
# Error fetching data for mercedes-benz-group: 'NoneType' object has no attribute 'text'
# Error fetching data for td-bank-group: 'NoneType' object has no attribute 'text'
# Error fetching data for taiwan-semiconductor: 'NoneType' object has no attribute 'text'
# Error fetching data for reliance-industries: 'NoneType' object has no attribute 'text'
# Error fetching data for bmw-group: 'NoneType' object has no attribute 'text'
# Error fetching data for lvmh-moët-hennessy-louis-vuitton: 'NoneType' object has no attribute 'text'
# Error fetching data for axa-group: 'NoneType' object has no attribute 'text'
# Error fetching data for santander: 'NoneType' object has no attribute 'text'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 10
#       8 for company_name in companies:
#       9     try:
# ---> 10         company_data = getData(company_name)  # Assuming you have your getData function defined
#      11         company_data_list.append(company_data)
#      12     except Exception as e:
#      13         # Handle the exception (e.g., print an error message)
#
# Cell In[11], line 17, in getData(company_name)
#      14 r = requests.get(url)
#      16 # Parse the HTML response using BeautifulSoup.
# ---> 17 soup = BeautifulSoup(r.text, "html.parser")
#      19 # Extract company basic information
#      20 # Get the company name.
#      21 company_name = soup.find("h1", class_="listuser-header__name")
#
# File c:\Users\sjess\Identificaci-n-de-Segmentos-de-Negocio\trabajo-grados\Lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File c:\Users\sjess\Identificaci-n-de-Segmentos-de-Negocio\trabajo-grados\Lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File c:\Users\sjess\Identificaci-n-de-Segmentos-de-Negocio\trabajo-grados\Lib\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File C:\Python312\Lib\html\parser.py:111, in HTMLParser.feed(self, data)
#     105 r"""Feed data to the parser.
#     106
#     107 Call this as often as you want, with as little or as much text
#     108 as you want (may include '\n').
#     109 """
#     110 self.rawdata = self.rawdata + data
# --> 111 self.goahead(0)
#
# File C:\Python312\Lib\html\parser.py:171, in HTMLParser.goahead(self, end)
#     169 if startswith('<', i):
#     170     if starttagopen.match(rawdata, i): # < + letter
# --> 171         k = self.parse_starttag(i)
#     172     elif startswith("</", i):
#     173         k = self.parse_endtag(i)
#
# File C:\Python312\Lib\html\parser.py:319, in HTMLParser.parse_starttag(self, i)
#     317 if not m:
#     318     break
# --> 319 attrname, rest, attrvalue = m.group(1, 2, 3)
#     320 if not rest:
#     321     attrvalue = None
#
# KeyboardInterrupt:

# %%
# Caso de que el scraping de de de funcionar creamso un archivo llamando "companies_base_1763.csv" con la información descargada
# Specify the path where you want to save the CSV file
csv_file_path = "C:\\Users\\sjess\\Identificaci-n-de-Segmentos-de-Negocio\\data\\processed\\companies_base_1763.csv"
# Save the DataFrame as a CSV file
df.to_csv(csv_file_path, index=False)  # Set index=False to exclude the index column
# Confirmation message
print(f"DataFrame has been saved to {csv_file_path}")

# %%
# Specify the path to your Excel file
csv_file_path = "C:\\Users\\sjess\\Identificaci-n-de-Segmentos-de-Negocio\\data\\processed\\companies_base_1763.csv"
# Load the Excel file into a DataFrame
df_financial_data = pd.read_csv(csv_file_path)
# Display the DataFrame
df_financial_data.head()
# Out:
#                                company_name stock_ticker  \
# 0                            JPMorgan Chase    NYSE: JPM
# 1  Saudi Arabian Oil Company (Saudi Aramco)          NaN
# 2                                      ICBC          NaN
# 3                   China Construction Bank          NaN
# 4                Agricultural Bank of China          NaN
#
#         company_location current_stock_price  \
# 0     New York, New York             $180.90
# 1  Dhahran, Saudi Arabia                 NaN
# 2         Beijing, China                 NaN
# 3         Beijing, China                 NaN
# 4         Beijing, China                 NaN
#
#                                          description  \
# 0  JPMorgan Chase & Co. is a financial holding co...
# 1  Saudi Arabian Oil Co. engages in the explorati...
# 2  Industrial & Commercial Bank of China Ltd. eng...
# 3  China Construction Bank Corp. engages in the p...
# 4  Agricultural Bank of China engages in the prov...
#
#                                             Industry Founded  \
# 0                     Banking and Financial Services    2000
# 1  Construction, Oil & Gas Operations, Mining and...    1933
# 2                     Banking and Financial Services    1984
# 3                                            Banking    1954
# 4                     Banking and Financial Services    1951
#
#          Headquarters Country/Territory CEO and Chair  ... President & CEO  \
# 0  New York, New York     United States   James Dimon  ...             NaN
# 1             Dhahran      Saudi Arabia           NaN  ...             NaN
# 2             Beijing             China           NaN  ...             NaN
# 3             Beijing             China           NaN  ...             NaN
# 4             Beijing             China           NaN  ...             NaN
#
#   CEO & Co-Founder Co-CEOs CEO & Founder Chairman and Co-CEO  \
# 0              NaN     NaN           NaN                 NaN
# 1              NaN     NaN           NaN                 NaN
# 2              NaN     NaN           NaN                 NaN
# 3              NaN     NaN           NaN                 NaN
# 4              NaN     NaN           NaN                 NaN
#
#   Chairman and Chief Executive Officer Co-Founder, Co-CEO and Chairman  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
#
#   Charter President President & Representative Director CEO and Chairman
# 0               NaN                                 NaN              NaN
# 1               NaN                                 NaN              NaN
# 2               NaN                                 NaN              NaN
# 3               NaN                                 NaN              NaN
# 4               NaN                                 NaN              NaN
#
# [5 rows x 85 columns]
